# %% [markdown]
# ---
#
#  ## **Exploratory Data Analysis (EDA) on Retail Sales Data**
#
#  ### By Jayapriya Sreenivasan
#
# ---

# %% [markdown]
# #### **Introduction**
#
# In today’s fast-paced retail environment, business needs data-driven insights to better understand customer behavior, optimize inventory, and boost sales. This project aims to conduct an Exploratory Data Analysis (EDA) on retail sales data to reveal patterns and trends that can support smarter decision-making and help drive business success.
#
#
# #### **About the Dataset**
#
# This dataset provides a snapshot of a fictional retail environment, capturing crucial details that reflect the core of retail operations and customer behavior.
#
# Columns in the dataset include:
#
# + **Transaction ID:**  A unique identifier for each transaction.
# + **Date:**  The date the transaction took place.
# + **Customer ID:**  A unique identifier for each customer.
# + **Gender:**  The gender of the customer.
# + **Age:**  The age of the customer.
# + **Product Category:**  The category of the product(s) purchased.
# + **Quantity:**  The number of items purchased in the transaction.
# + **Price per Unit:**  The price of a single unit of the product.
# + **Total Amount:**  The total amount spent in the transaction (Quantity * Price per Unit).
#
# #### **Business Task**
#
# The business task is to analyze retail sales data to identify trends, customer behavior, and patterns that will help optimize products, target customers, and improve sales strategies.
#
# #### **Objective**
#
# The objective of this project is to conduct exploratory data analysis (EDA) on retail sales data to uncover insights into customer demographics, sales trends, and product preferences. These insights will support data-driven decisions to enhance business performance and customer satisfaction.
#
# #### **Data sources**
#
# This dataset provided from [Retail Sales Dataset](https://www.kaggle.com/datasets/mohammadtalib786/retail-sales-dataset/data) is fictional and was created for the purpose of conducting retail sales analysis, for the year 2023 and 2024 January.
#
# #### **Limitations**
#
# Since the dataset is fictional, the insights and patterns identified may not fully reflect real-world retail scenarios or customer behavior.
#
# --------

# %% [markdown]
# # __*Process*__
#
# ##### **Tools Used to process data:**
#
# I used Visual Studio Code for running Python scripts for the data cleansing process.
#
# ##### **Steps involved in the Process**
#
# * Load the Data: Import the dataset and necessary libraries.
# * Clean the Data: Handle missing values, correct data types, and remove any outliers.
# * Verify Data Integrity: Ensuring that the dataset is accurate, consistent, and suitable for analysis.

# %%
# Importing the Libraries

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
# Loading the Datasets 

df = pd.read_csv(r'C:\Users\chanv\OIBSIP\data\retail_sales_dataset.csv')

# %%
# Showing the First few rows of the data

print(df.head())
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  Quantity  Price per Unit  Total Amount
# 0               1  2023-11-24     CUST001    Male   34           Beauty         3              50           150
# 1               2  2023-02-27     CUST002  Female   26         Clothing         2             500          1000
# 2               3  2023-01-13     CUST003    Male   50      Electronics         1              30            30
# 3               4  2023-05-21     CUST004    Male   37         Clothing         1             500           500
# 4               5  2023-05-06     CUST005    Male   30           Beauty         2              50           100

# %%
# Converting 'Date' column to Datetime

df['Date'] = pd.to_datetime(df['Date'])

# %%
# Showing the data info

df.info()
print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB

# %%
# Consistent Formatting in text fields

df['Gender'] = df['Gender'].str.lower()
df['Product Category'] = df['Product Category'].str.lower()
print(df['Gender'].unique())
print(df['Product Category'].unique())
# Out:
# ['male' 'female']
# ['beauty' 'clothing' 'electronics']

# %%
# Checking for missing values

print()
print("\n",df.isnull().sum())
# Out:
#  Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
# Checking for Duplicates:

print("\n", df.duplicated().sum())
# Out:
#  0

# %% [markdown]
# ------
#
# ##### **Steps taken for data cleansing**
#
# * Missing Values: There are no missing values in the dataset.
# * Duplicate Data: There are no duplicates in the dataset.
# * Data Types: Numeric columns such as Age, Quantity, Price per Unit and Total Amount have appropriate data types(int64).
# * Consistent Formatting: Checked the format in Text Feilds using str.lower().
# * Date Time: The Date column has been successfully converted to datetime.
#
# -------

# %% [markdown]
# # __*Analysis and Visualization*__
#
# Data is ready for Analysis.
#
# ##### **Key Tasks for Analysis:**
#
# 1. **Descriptive Statistics**: Calculate mean, median, mode, and standard deviation for key variables like sales and quantity.
# 2. **Customer Segmentation**: Group data by customer demographics such as age, gender, and purchasing habits.
# 3. **Product Analysis**: Identify trends in product categories, most popular products, and sales distribution across different categories.
# 4. **Time Series Analysis**: Explore trends over time (e.g., monthly or seasonal sales).
#
# ##### **Tasks for Visualization:**
#
# + Presenting insights through bar charts, line plots, and heatmaps.
# + I chose Visual Studio Code to showcase the findings using Python.

# %%
#1: Descriptive Statistics: Calculate basic statistics (mean, median, mode, standard deviation).

mean_values = df.select_dtypes(include =['number']).mean()
median_values = df.select_dtypes(include =['number']).median()
mode_values = df.select_dtypes(include =['number']).mode().iloc[0]  # Selecting the first value
std_values = df.select_dtypes(include =['number']).std()

print("\n Mean:\n", mean_values)
print("\n Median:\n", median_values)
print("\n Mode:\n", mode_values)
print("\n Stand_D:\n", std_values)
# Out:
#  Mean:
#  Transaction ID    500.500
# Age                41.392
# Quantity            2.514
# Price per Unit    179.890
# Total Amount      456.000
# Month               6.549
# dtype: float64
#
#  Median:
#  Transaction ID    500.5
# Age                42.0
# Quantity            3.0
# Price per Unit     50.0
# Total Amount      135.0
# Month               6.0
# dtype: float64
#
#  Mode:
#  Transaction ID     1.0
# Age               43.0
# Quantity           4.0
# Price per Unit    50.0
# Total Amount      50.0
# Month              5.0
# Name: 0, dtype: float64
#
#  Stand_D:
#  Transaction ID    288.819436
# Age                13.681430
# Quantity            1.132734
# Price per Unit    189.681356
# Total Amount      559.997632
# Month               3.452755
# dtype: float64

# %% [markdown]
# **Insights:**
#
# + Customer Age: The customers' ages range from 18 to 64, with a mean age of approximately 41.4 years.
# + Quantity: The quantity of products sold per transaction ranges from 1 to 4, with a median of 3.
# + Price per Unit: The price per unit ranges from $25 to $500, with an average price of approximately $179.89.
# + Total Amount: The total transaction amounts range from $25 to $2000, with an average transaction total of $456.
# + Highest variability in Total Amount Std is $560 and Price per Unit Std is $189.68, indicating diverse price ranges and spending patterns.
#
# ----

# %%
# 2: Time Series Analysis (Sales trends over time)

daily_sales = df.groupby('Date')['Total Amount'].sum()
monthly_sales = daily_sales.resample('M').sum().reset_index()
monthly_sales['Date'] = monthly_sales['Date'].dt.strftime('%Y-%m')
print("\nMonthly Sales Trends:")
monthly_sales
# Out:
# Monthly Sales Trends:
#        Date  Total Amount
# 0   2023-01         35450
# 1   2023-02         44060
# 2   2023-03         28990
# 3   2023-04         33870
# 4   2023-05         53150
# 5   2023-06         36715
# 6   2023-07         35465
# 7   2023-08         36960
# 8   2023-09         23620
# 9   2023-10         46580
# 10  2023-11         34920
# 11  2023-12         44690
# 12  2024-01          1530

# %%
# Visualization using Line plot to show how sales vary over time (Monthly).

plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Total Amount', data = monthly_sales, marker='o', color='green', linestyle='-')
plt.title('Sales Trends Over Time (Monthly)', fontsize=14)
plt.xlabel('Date')
plt.ylabel('Total Sales ($)')

# Adding text labels on the points
for i in range(len(monthly_sales)):                          
    plt.text(i, monthly_sales['Total Amount'].iloc[i], f"${monthly_sales['Total Amount'].iloc[i]:.0f}", ha='center', 
             va='bottom', fontsize=10)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:**
#
# + The sales peaks in May 2023 with a high of $53,150. This could be because of a seasonal demand.
# + The sales declines in January 2024, with sales going down to $1,530. Indicates a post holiday slowdown.

# %%
# 3: Customer and Product Analysis: Analyzing Customer Age and Gender Influence on Purchasing Behavior

age_bins = [18, 24, 34, 44, 54, 64, 100]  # Age category and labels for ranges
age_labels = ['18-24', '25-34', '35-44', '45-54', '55-64', '65+']
df['Age Range'] = pd.cut(df['Age'], bins = age_bins, labels = age_labels, right = False) #New column (Age Range)
gender_age_sales = df.groupby(['Gender', 'Age Range'])['Total Amount'].sum().reset_index()
print("\nTotal Sales by Age Range and Gender:")
gender_age_sales
# Out:
# Total Sales by Age Range and Gender:
#     Gender Age Range  Total Amount
# 0   female     18-24         34170
# 1   female     25-34         41550
# 2   female     35-44         61425
# 3   female     45-54         44660
# 4   female     55-64         44710
# 5   female       65+          6325
# 6     male     18-24         35065
# 7     male     25-34         44170
# 8     male     35-44         44635
# 9     male     45-54         49630
# 10    male     55-64         46860
# 11    male       65+          2800

# %%
# Visualization using a Barchart to show how age and gender impact spending:

plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Age Range', y='Total Amount', hue='Gender', data=gender_age_sales, palette = "rocket")
plt.title('Total Sales by Age Range and Gender')
plt.xlabel('Age Range')
plt.ylabel('Total Sales (Total Amount)')

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.0f'),
                      (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 9),
                        textcoords = 'offset points')

# %% [markdown]
# **Insights:**
#
# + Females in the age range 35-44 have higher sales ($61,425) than males ($44,635).
# + The total amount spent by females is more than males.

# %%
# 4: Top Product Categories

pcategory_sales = df.groupby('Product Category')['Total Amount'].sum().reset_index()
print("\nTop product categories:")
pcategory_sales
# Out:
# Top product categories:
#   Product Category  Total Amount
# 0           beauty        143515
# 1         clothing        155580
# 2      electronics        156905

# %%
# Visualization using Bar chart showing Total Sales per product category.

plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x='Product Category', y='Total Amount', data=pcategory_sales, palette="icefire")
plt.title('Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales ($)')

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.0f'),  
                      (p.get_x() + p.get_width() / 2., p.get_height()),  
                      ha = 'center', va = 'center', 
                      xytext = (0, 9), textcoords='offset points') 
plt.show()

# %% [markdown]
# **Insights:**
#
# + Electronics has the highest total sales at $156,905, indicating strong consumer demand.
# + Clothing follows closely with total sales of $155,580, indicates seasonal buying trends.
# + Beauty products total $143,515, ranking third, indicates it has the lowest sales compared to the other Categories.

# %%
# 5: Age, Spending, and Product Preferences (Relationships)

age_product_sales = df.groupby(['Age Range', 'Product Category'])['Total Amount'].sum().unstack() #pivoting
print("\nSpending by age and product categories:")
age_product_sales
# Out:
# Spending by age and product categories:
# Product Category  beauty  clothing  electronics
# Age Range
# 18-24              26020     20010        23205
# 25-34              24020     40090        21610
# 35-44              36750     29625        39685
# 45-54              33065     31350        29875
# 55-64              21330     28950        41290
# 65+                 2330      5555         1240

# %%
# Visualization using Heatmap to analyze which product categories appeal most to different age groups.

plt.figure(figsize = (14, 8))
sns.heatmap(age_product_sales, cmap = 'coolwarm', annot = True, fmt='.0f')
plt.title('Total Spending by Age and Product Category')
plt.show()

# %% [markdown]
# **Insights:**
#
# + The highest purchase of beauty products is in the 35-44 age range spending $36,750 and the lowest purchases are seen in the 65+ age range spending $2,330.
# + The 25-34 age range shows the highest spending on clothing of $40,090 and the lowest purchase is from the 65+ age range spending $5,555.
# + The 55-64 age range leads in electronics purchases of $41,290 and the 65+ age group has the least electronics purchases of $1,240.
# + Overall Trends : clothing sales is highest in 18-34 age category.
#                    Electronics sales is highest in 55-64 age category.
#                    people with age of 65+ years purchase less in all categories.

# %%
# 6: Seasonal Trends (Analyzing by month)

df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
monthly_product_sales = df.groupby(['Month', 'Product Category'])['Total Amount'].sum().unstack()
print("\nSeasonal Trends:") 
monthly_product_sales
# Out:
# Seasonal Trends:
# Product Category  beauty  clothing  electronics
# Month
# 1                  13930     13125         9925
# 2                  14035     14560        15465
# 3                  10545     15065         3380
# 4                  11905     13940         8025
# 5                  12450     17455        23245
# 6                  10995     10170        15550
# 7                  16090      8250        11125
# 8                   9790     12455        14715
# 9                   6320      9975         7325
# 10                 15355     13315        17910
# 11                  9700     15200        10020
# 12                 12400     12070        20220

# %%
# Visualization monthly sales (seasonal trends)

plt.figure(figsize = (14, 8))
sns.heatmap(monthly_product_sales, cmap = 'coolwarm', annot = True, fmt='.0f')
plt.title('Total Spending by Month and Product Category')
plt.show()

# %% [markdown]
# **Insights:**
#
# + The highest sales for electronics occured in May ($23,245) and December ($20,220).
# + Clothing sales was highest in May ($17,455) and November ($15,200) .
# + Beauty sales was the lowest. It spiked in July ($16,090) and October ($15,355).

# %%
# 7: Number of Items Bought Per Transaction

item_count_sales = df.groupby('Quantity')['Transaction ID'].count().reset_index(name='Transaction Count')
print("\nItems per transaction:") 
item_count_sales
# Out:
# Items per transaction:
#    Quantity  Transaction Count
# 0       1.0                253
# 1       2.0                243
# 2       3.0                241
# 3       4.0                263

# %%
# Visualization of Average Sales by Quantity of Items per Transaction

bar_plot = item_count_sales.plot(kind='bar', x='Quantity', y='Transaction Count', color = sns.color_palette("rocket"), 
                                    figsize=(10, 6),  legend=False)
plt.title('Count of Transactions by Quantity')
plt.ylabel('Transaction Count')
plt.xlabel('Quantity')

for p in bar_plot.patches:
    tcount_value = p.get_height()  # Get the height (count) of the current bar
    total_tcount = item_count_sales['Transaction Count'].sum()
    percentage_value = (tcount_value / total_tcount) * 100  # Calculate percentage for the current bar
    bar_plot.annotate(f'{tcount_value} ({percentage_value:.1f}%)',  
                      (p.get_x() + p.get_width() / 2., tcount_value),  
                      ha='center', va='bottom', 
                      xytext=(0, 5), textcoords='offset points')  
 
plt.show()

# %% [markdown]
# **Insights:**
# + There were 263 occurrences where transaction had more then 4 items which was highest among all transactions
# + 4 items might indicate popular product bundles.

# %%
# 8: Product Price Distribution by Category

df['Quantity'] = df['Total Amount'] / df['Price per Unit']
category_gender_group = df.groupby(['Product Category', 'Gender']).agg(
    {'Total Amount': 'sum','Quantity': 'sum'}).reset_index()
category_gender_group['Avg Price per Unit'] = category_gender_group['Total Amount'] / category_gender_group['Quantity']

print("\nProduct price distribution")
category_gender_group
# Out:
# Product price distribution
#   Product Category  Gender  Total Amount  Quantity  Avg Price per Unit
# 0           beauty  female         74830     418.0          179.019139
# 1           beauty    male         68685     353.0          194.575071
# 2         clothing  female         81275     441.0          184.297052
# 3         clothing    male         74305     453.0          164.028698
# 4      electronics  female         76735     439.0          174.794989
# 5      electronics    male         80170     410.0          195.536585

# %%
# Visualizing using bar plot for Total Amount and Avg Price per Unit by Product Category and Gender

plt.figure(figsize=(12, 8))


bar_plot = sns.barplot(x='Product Category', y='Avg Price per Unit', hue='Gender', data=category_gender_group, palette='rocket')
plt.title('Average Price per Unit by Product Category and Gender')
plt.xlabel('Product Category')
plt.ylabel('Average Price per Unit')

for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.0f'),  
                      (p.get_x() + p.get_width() / 2., p.get_height()),  
                      ha = 'center', va = 'center', 
                      xytext = (0, 9), textcoords = 'offset points')
plt.legend(title='Gender', loc='lower right')
plt.show()

# %% [markdown]
# **Insights:**
# + Beauty: Males pay a higher average price per unit $195 than females $179.
# + Clothing: Females spend more on average per unit $184 than males $164.
# + Electronics: Males pay higher average price per unit $196 compared to females $175.
#
# --------
#
# --------

# %% [markdown]
# # __*Share*__
#
# Overall insights of the data based on the analysis:
#
# 1. **Total Sales by Category:**
#  * _Insights: Electronics has the highest sales share at 33.0%, followed closely by clothing at 32.6%. Beauty lags slightly at 30.1%._
#
# 2. **Time Series Analysis (Sales trends over time):**
# * _*Peak sales in*: May ($53,150), followed by October ($46,580) and November ($44,690)._
# * _*Lowest sales*: January 2024 ($1,530), likely influenced by post-holiday._
#
# _**Recommendation:** Focus marketing campaigns with special attention to promotions in May and October, which show higher sales ._
#
# 3. **Customer Age and Gender Influence:**
#
# * _Top Age Groups: 35-44 (Male: $44,635 & Female: $61,425), followed by 45-54 (Male: $49,630 & Female: $44,660)_
# * _Top Gender: Female customers generated more sales overall in the 35-44 age group ($61,425)._
#
# _**Recommendation:** Targeting male and female audiences aged 35-44 with personalized product offerings and marketing efforts._
#
# 4. **Top Product Categories:**
#
# * _Electronics: $156,905 (33.8%)_
# * _Clothing: $155,580 (33.5%)_
# * _Beauty: $143,515 (30.9%)._
#
# _**Recommendation:** Increase inventory and marketing in the electronics and clothing categories due to strong demand and potential revenue growth._
#
#
# 5. **Age, Spending, and Product Preferences:**
#
# * _Electronics dominate in the 55-64 age group with with $41,290 in sales._
# * _Clothing is popular among customers aged 25-34 with $40,090 in sales._
# * _Beauty is popular to customers aged 35-44 with $36,750 in sales._
#
# _**Recommendation:** Tailor advertising for beauty products to older demographics (35-44) and focus clothing promotions on younger audiences (25-34)._
#
#
# 6. **Seasonal Trends:**
#
# * _High Sales Months: In May Clothing is ($17,455) and Electronics ($23,245) and in October Beauty ($15,355) and Electronics ($17,910)._
# * _Low Sales Months: September (Beauty: $6,320, Electronics: $7,325)._
#
# _**Recommendation:** Run promotions for beauty and clothing products in May and October, and consider flash sales or discounts in slow months (e.g., September)._
#
# 7. **Items Bought Per Transaction:**
#
# * _4 items per transaction (26.3%), followed by 1 item per transaction (25.3%)._
#
# _**Recommendation:** Encourage larger purchases through bundle offers and discounts for bulk buying, since higher transaction volumes correlate with greater revenue._
#
# 8. **Product Price Distribution by Category and Gender:**
#
# _*Average Price per Unit:_
# _Beauty: $179 (Female: $179.02, Male: $194.57)_
# _Clothing: $174 (Female: $184.30, Male: $164.03)_
# _Electronics: $185 (Female: $174.79, Male: $195.54)_
#
# _**Recommendation:** Maintain diverse price points to accommodate both genders, with slightly higher pricing on electronics and beauty for male audiences._
#
#
# #### **Overall Recommendations:**
#
# + Target Audience by Gender:
# Focus on Beauty and Clothing for female customers, Electronics and Beauty for male customers. Adjust marketing and promotions accordingly.
#
# + Price Optimization:
# Since Beauty and Electronics have higher average prices compared to Clothing which sells in larger volumes, it might be beneficial to experiment with bundle discounts or promotional pricing in the Clothing category.
#
# + Seasonal Promotions:
# Tailor promotional campaigns around peak times: Electronics for the holiday season (December), Beauty in mid-summer (July), and Clothing in spring (May).
# This inference summarizes your product sales, pricing, and customer behavior based on the data provided.
